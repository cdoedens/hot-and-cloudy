# %% [markdown]
# Regions:
# - GCCSA
#   - 1GSYD
#   - 2GMEL
#   - 3GBRI
#   - 4GADE
#   - 5GPER
#   - 6GHOB
#   - 7GDAR
#   - 8ACTE
#
# Tilt:
# - fixed
# - single_axis
#
# Five args must be submitted for the script to run:
# - Start date
# - End date
# - Region
# - Variable
# - Tilt

# %%
import subprocess
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

script_to_run = 'CONCURRENT-FUTURES-SOLAR'

region = 'GCCSA_1GSYD'
tilt = 'fixed'

# First full month of data (Aug '15) to latest (Jan '25)
first = '1-8-2015'
num_batches = 12 * 9 + 6

first_dt = datetime.strptime(first, "%d-%m-%Y")
dates = []
for x in range(num_batches):
    start_dt = first_dt + relativedelta(months =  x)
    start_date = start_dt.strftime("%d-%m-%Y")
    end_dt = start_dt + relativedelta(months = 1) - relativedelta(days=1)
    end_date = end_dt.strftime("%d-%m-%Y")
    dates.append((start_date, end_date))

if region[1].upper() == 'ALL':
    ncpus = 13
else:
    ncpus = 48
for start, end in dates:
    
    # Generate a unique file name based on iteration
    joboutdir = '/home/548/cd3022/hot-and-cloudy/code/qsub/'
    job_script_filename = joboutdir + f'{script_to_run}___' + start + '_' + region '.qsub'
    
    # Open the file for writing
    with open(job_script_filename, "w") as f3:
        f3.write('#!/bin/bash \n')
        f3.write('#PBS -l walltime=1:00:00 \n')
        f3.write('#PBS -l mem=192GB \n')
        f3.write(f'#PBS -l ncpus={ncpus} \n')
        f3.write('#PBS -l jobfs=10GB \n')
        f3.write('#PBS -l storage=gdata/hh5+gdata/gb02+gdata/rv74+gdata/rt52 \n')
        f3.write('#PBS -l other=hyperthread \n')
        f3.write('#PBS -q normal \n')
        f3.write('#PBS -P er8 \n')
        f3.write(f'#PBS -o /home/548/cd3022/hot-and-cloudy/logs/{script_to_run}_{var}_{region}_{start}.oe \n')
        f3.write('#PBS -j oe \n')
        f3.write('module use /g/data3/hh5/public/modules \n')
        f3.write('module load conda/analysis3 \n')
        f3.write('conda \n')
        f3.write(f'python3 /home/548/cd3022/hot-and-cloudy/code/{script_to_run}.py {start} {end} {region} {var} {tilt}\n')


    # Submit the generated script to the job scheduler (PBS) using qsub
    try:
        # Run the qsub command and submit the script
        subprocess.run(['qsub', job_script_filename], check=True)
        print(f"Job script {job_script_filename} submitted successfully.")
    except subprocess.CalledProcessError as e:
        print(f"Error submitting job script {job_script_filename}: {e}")
# Out:
# 142727804.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-08-2015.qsub submitted successfully.
# 142727805.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-09-2015.qsub submitted successfully.
# 142727806.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-10-2015.qsub submitted successfully.
# 142727807.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-11-2015.qsub submitted successfully.
# 142727808.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-12-2015.qsub submitted successfully.
# 142727809.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-01-2016.qsub submitted successfully.
# 142727810.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-02-2016.qsub submitted successfully.
# 142727811.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-03-2016.qsub submitted successfully.
# 142727812.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-04-2016.qsub submitted successfully.
# 142727813.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-05-2016.qsub submitted successfully.
# 142727814.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-06-2016.qsub submitted successfully.
# 142727815.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-07-2016.qsub submitted successfully.
# 142727816.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-08-2016.qsub submitted successfully.
# 142727817.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-09-2016.qsub submitted successfully.
# 142727818.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-10-2016.qsub submitted successfully.
# 142727819.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-11-2016.qsub submitted successfully.
# 142727820.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-12-2016.qsub submitted successfully.
# 142727821.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-01-2017.qsub submitted successfully.
# 142727822.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-02-2017.qsub submitted successfully.
# 142727823.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-03-2017.qsub submitted successfully.
# 142727824.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-04-2017.qsub submitted successfully.
# 142727825.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-05-2017.qsub submitted successfully.
# 142727826.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-06-2017.qsub submitted successfully.
# 142727827.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-07-2017.qsub submitted successfully.
# 142727828.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-08-2017.qsub submitted successfully.
# 142727829.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-09-2017.qsub submitted successfully.
# 142727830.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-10-2017.qsub submitted successfully.
# 142727831.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-11-2017.qsub submitted successfully.
# 142727832.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-12-2017.qsub submitted successfully.
# 142727833.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-01-2018.qsub submitted successfully.
# 142727834.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-02-2018.qsub submitted successfully.
# 142727835.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-03-2018.qsub submitted successfully.
# 142727836.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-04-2018.qsub submitted successfully.
# 142727837.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-05-2018.qsub submitted successfully.
# 142727838.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-06-2018.qsub submitted successfully.
# 142727839.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-07-2018.qsub submitted successfully.
# 142727840.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-08-2018.qsub submitted successfully.
# 142727841.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-09-2018.qsub submitted successfully.
# 142727842.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-10-2018.qsub submitted successfully.
# 142727843.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-11-2018.qsub submitted successfully.
# 142727844.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-12-2018.qsub submitted successfully.
# 142727845.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-01-2019.qsub submitted successfully.
# 142727846.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-02-2019.qsub submitted successfully.
# 142727847.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-03-2019.qsub submitted successfully.
# 142727848.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-04-2019.qsub submitted successfully.
# 142727849.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-05-2019.qsub submitted successfully.
# 142727850.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-06-2019.qsub submitted successfully.
# 142727851.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-07-2019.qsub submitted successfully.
# 142727852.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-08-2019.qsub submitted successfully.
# 142727853.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-09-2019.qsub submitted successfully.
# 142727854.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-10-2019.qsub submitted successfully.
# 142727855.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-11-2019.qsub submitted successfully.
# 142727856.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-12-2019.qsub submitted successfully.
# 142727857.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-01-2020.qsub submitted successfully.
# 142727858.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-02-2020.qsub submitted successfully.
# 142727859.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-03-2020.qsub submitted successfully.
# 142727860.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-04-2020.qsub submitted successfully.
# 142727861.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-05-2020.qsub submitted successfully.
# 142727862.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-06-2020.qsub submitted successfully.
# 142727863.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-07-2020.qsub submitted successfully.
# 142727864.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-08-2020.qsub submitted successfully.
# 142727865.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-09-2020.qsub submitted successfully.
# 142727866.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-10-2020.qsub submitted successfully.
# 142727867.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-11-2020.qsub submitted successfully.
# 142727868.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-12-2020.qsub submitted successfully.
# 142727869.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-01-2021.qsub submitted successfully.
# 142727870.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-02-2021.qsub submitted successfully.
# 142727871.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-03-2021.qsub submitted successfully.
# 142727872.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-04-2021.qsub submitted successfully.
# 142727873.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-05-2021.qsub submitted successfully.
# 142727874.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-06-2021.qsub submitted successfully.
# 142727875.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-07-2021.qsub submitted successfully.
# 142727876.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-08-2021.qsub submitted successfully.
# 142727877.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-09-2021.qsub submitted successfully.
# 142727878.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-10-2021.qsub submitted successfully.
# 142727879.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-11-2021.qsub submitted successfully.
# 142727880.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-12-2021.qsub submitted successfully.
# 142727881.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-01-2022.qsub submitted successfully.
# 142727882.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-02-2022.qsub submitted successfully.
# 142727883.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-03-2022.qsub submitted successfully.
# 142727884.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-04-2022.qsub submitted successfully.
# 142727885.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-05-2022.qsub submitted successfully.
# 142727886.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-06-2022.qsub submitted successfully.
# 142727887.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-07-2022.qsub submitted successfully.
# 142727888.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-08-2022.qsub submitted successfully.
# 142727889.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-09-2022.qsub submitted successfully.
# 142727890.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-10-2022.qsub submitted successfully.
# 142727891.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-11-2022.qsub submitted successfully.
# 142727892.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-12-2022.qsub submitted successfully.
# 142727893.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-01-2023.qsub submitted successfully.
# 142727894.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-02-2023.qsub submitted successfully.
# 142727895.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-03-2023.qsub submitted successfully.
# 142727896.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-04-2023.qsub submitted successfully.
# 142727897.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-05-2023.qsub submitted successfully.
# 142727898.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-06-2023.qsub submitted successfully.
# 142727899.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-07-2023.qsub submitted successfully.
# 142727900.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-08-2023.qsub submitted successfully.
# 142727901.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-09-2023.qsub submitted successfully.
# 142727902.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-10-2023.qsub submitted successfully.
# 142727903.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-11-2023.qsub submitted successfully.
# 142727904.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-12-2023.qsub submitted successfully.
# 142727905.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-01-2024.qsub submitted successfully.
# 142727906.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-02-2024.qsub submitted successfully.
# 142727907.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-03-2024.qsub submitted successfully.
# 142727908.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-04-2024.qsub submitted successfully.
# 142727909.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-05-2024.qsub submitted successfully.
# 142727910.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-06-2024.qsub submitted successfully.
# 142727911.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-07-2024.qsub submitted successfully.
# 142727912.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-08-2024.qsub submitted successfully.
# 142727913.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-09-2024.qsub submitted successfully.
# 142727914.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-10-2024.qsub submitted successfully.
# 142727915.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-11-2024.qsub submitted successfully.
# 142727916.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-12-2024.qsub submitted successfully.
# 142727917.gadi-pbs
# Job script /home/548/cd3022/hot-and-cloudy/code/qsub/CONCURRENT-FUTURES-SOLAR___01-01-2025.qsub submitted successfully.
